# %%
code=input("Enter Code")

match code:
    case "200":
        print("ok")
    case "400":
        print("Bad request")
    case "501":
        print("Internal Server Error")
    case _:
        print("default")
# Out:
# Enter Code 400
# Bad request
