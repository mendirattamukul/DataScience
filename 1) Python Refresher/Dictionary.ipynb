# %%
#Declaration
dicti={}#empty dictionay
print(type(dicti))
dicti={"name":"mukul","age":28}
print(type(dicti))
#dicti=dict(name="mukul",age=28)#with dictionary constructor
# Out:
# <class 'dict'>
# <class 'dict'>

# %%
#accessing dictionay
print(dicti["name"])
print(dicti.get("age"))
print(dicti.get("designation"),"not found")#with default value
# Out:
# mukul
# 28
# None not found

# %%
#methods
for key in dicti.keys():
    print(key)
# Out:
# name
# age

# %%
for key in dicti.values():
    print(key)
# Out:
# mukul
# 28

# %%
dicti.update({"height":"166 CM"})

# %%
item=dicti.pop("weight","not found")
print(item)
# Out:
# not found

# %%
item=dicti.pop("height","not found")
print(item)
# Out:
# 166 CM

# %%
item=dicti.popitem()

# %%
item
# Out:
# ('age', 28)

# %%
type(item)
# Out:
# tuple

# %%
item[0]
# Out:
# 'age'

# %%
item[1]
# Out:
# 28

# %%
items=dicti.items()

# %%
type(items)
# Out:
# dict_items

# %%
dicti.clear()

# %%
print(dicti)
# Out:
# {}

# %%
for item in dicti.items():
   print(f"Key={item[0]} value={item[1]}")
# Out:
# Key=name value=mukul
# Key=age value=28
# Key=city value=faridbabad

# %%
dicti["city"]="faridbabad"
