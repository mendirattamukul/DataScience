# %%
str="Hello I Am Learnig Python"
str.lower()
# Out:
# 'hello i am learnig python'

# %%
str.upper()
# Out:
# 'HELLO I AM LEARNIG PYTHON'

# %%
len(str)
# Out:
# 25

# %%
str[0]
# Out:
# 'H'

# %%
str[1]
# Out:
# 'e'

# %%
str2="""This Is 
Multiline String"""

# %%
print(str2)
# Out:
# This Is
# Multiline String

# %%
str[-1] ##negative index starts from back add len to make negative index to possitive
# Out:
# 'n'

# %%
str.strip()
# Out:
# 'Hello I Am Learnig Python'

# %%
str.split()
# Out:
# ['Hello', 'I', 'Am', 'Learnig', 'Python']

# %%
name='mukul'
age='27'
str=f"{name} is learning python at the age of {age}"#This is called fstring

# %%
print(str)
# Out:
# mukul is learning python at the age of 27

# %%
str[0]='w'#error because string is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 str[0]='w'
#
# TypeError: 'str' object does not support item assignment

# %%
str.find("2")
# Out:
# 39

# %%
len(str)
# Out:
# 41
