# %%
#tuples are immutable and they are ordered
tup=()#empty tuple

# %%
tup
# Out:
# ()

# %%
tu=(1)

# %%
tu
# Out:
# 1

# %%
type(tu)
# Out:
# int

# %%
type(tup)
# Out:
# tuple

# %%
tu=(1,)#,is necessary for single element

# %%
type(tu)
# Out:
# tuple

# %%
tuple=(3,4,2,5,1)
tuple.count(3)
# Out:
# 1

# %%
tuple.index(4)
# Out:
# 1

# %%
tuple[1:3]#slicing in tuple
# Out:
# (4, 2)

# %%
#packing and unpacking in tuple
person=("mukul",28,"Developer")#packing
name,age,designation=person#unpacking

# %%
name
# Out:
# 'mukul'

# %%
age
# Out:
# 28

# %%
designation
# Out:
# 'Developer'
