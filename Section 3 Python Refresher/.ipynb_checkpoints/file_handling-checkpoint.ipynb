# %%
f=open("test.txt","r")

# %%
f
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='cp1252'>

# %%
print(f.read())
# Out:
# Hello i am
# already existing file

# %%
f.close()

# %%
lst=f.readlines()

# %%
lst
# Out:
# ['Hello i am \n', 'already existing file']

# %%
f.close()

# %%
f=open("new file.txt","w")

# %%
f.write("Hello There")
# Out:
# 11

# %%
f.close()

# %%
f2=open("new file.txt","a")
f2.write("\nHello Wolrd 2")
f2.write("\nHello Wolrd 2")
f2.write("\nHello Wolrd 2")

f2.close()

# %%
#instead of closing file we can use with same as using in c#
with open("new file.txt","r") as f:
    print(f.read())
# Out:
# Hello There
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2
# Hello Wolrd 2

# %%
import os
if os.path.exists("new file.txt"):
    os.remove("new file.txt")
else:
    print("not exists")
# Out:
# not exists
