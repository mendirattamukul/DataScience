# %%
#declaration
list=[]#empty list
list2=[1,2,3,4,5]#list of numbers
list3=[1,2,"apple",True]#List with diff data types

# %%
#methods
list.append(2)
print(list)
# Out:
# [2]

# %%
list.append(4)
print(list)
# Out:
# [2, 4]

# %%
list.extend([5,6])
print(list)
# Out:
# [2, 4, 5, 6]

# %%
list.append(6)

# %%
list.append(5
           )
print(list)
# Out:
# [2, 4, 5, 6, 6, 5]

# %%
list.count(6)
# Out:
# 2

# %%
list.count(3)
# Out:
# 0

# %%
list.clear()

# %%
list
# Out:
# []

# %%
list.extend([1,2,3,4,5])

# %%
list.index(3)
# Out:
# 2

# %%
list.index(7)#will give error if not found
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 list.index(7)
#
# ValueError: 7 is not in list

# %%
list.sort()

# %%
list
# Out:
# [1, 2, 3, 4, 5]

# %%
lst2=list.copy()

# %%
lst2
# Out:
# [1, 2, 3, 4, 5]

# %%
list.append(7)

# %%
list
# Out:
# [1, 2, 3, 4, 5, 7]

# %%
lst2
# Out:
# [1, 2, 3, 4, 5]

# %%
list.append([1,2])

# %%
lst=list.copy()

# %%
list
# Out:
# [1, 2, 3, 4, 5, 7, [1, 2]]

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 7, [1, 2]]

# %%
element=list.pop()

# %%
element
# Out:
# [1, 2]

# %%
list
# Out:
# [1, 2, 3, 4, 5, 7]

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 7, [1, 2]]

# %%
list.append([1,2])

# %%
list
# Out:
# [1, 2, 3, 4, 5, 7, [1, 2]]

# %%
lst=list.copy()

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 7, [1, 2]]

# %%
list[6]=[2,3]

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 7, [1, 2]]

# %%
list
# Out:
# [1, 2, 3, 4, 5, 7, [2, 3]]
