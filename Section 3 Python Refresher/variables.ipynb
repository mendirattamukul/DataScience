# %%
print("hello")
# Out:
# hello

# %%
a=5

# %%
b=5

# %%
a+b
# Out:
# 10

# %%
str="mukul"

# %%
print(str)
# Out:
# mukul

# %%
isValid=True

# %%
print(isValid)
# Out:
# True

# %%
c="123"

# %%
d="321"

# %%
c+d
# Out:
# '123321'

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# str

# %%
int(c)
# Out:
# 123

# %%
int(c)+int(d)
# Out:
# 444
