# %%
#pemdas
print(2 ** 3 ** 2)# it will be solved as 3 to power 2 which will be 9 then 2 to the power 9 
print((10 + 2) * 3 )#12*3=36
print( 10 + 2 * 3)#16
print(10/2*3)#15
print(10*2/3)#6.6
print(10*2**2**3*2/2)#(10*2**8*2/2) (10*256*2/2) (2560*2/2) (5120/2) (2560)
# Out:
# 512
# 36
# 16
# 15.0
# 6.666666666666667
# 2560.0
