# %%
import pandas as pd
pd.read_csv("1745500125912-data.csv")

# %%
df=pd.read_csv("1745500125912-data.csv",usecols=["Actor","Film"],nrows=5)

# %%
df.to_csv("output.csv",index=False)

# %%
df=pd.read_excel("Project-Management-Sample-Data.xlsx")
dfMarketing=df[df["Project Name"]=="Marketing"]
dfProductDev=df[df["Project Name"]=="Product Dev"]
dfCustomerSvc=df[df["Project Name"]=="Customer Svc"]
with pd.ExcelWriter("Details.xlsx") as Writer:
    dfMarketing.to_excel(Writer,sheet_name="Marketing",index=False)
    dfProductDev.to_excel(Writer,sheet_name="Product Dev",index=False)
    dfCustomerSvc.to_excel(Writer,sheet_name="Customer Service",index=False)

# %%
dfProductDev
# Out:
#   Project Name              Task Name Assigned to Start Date  Days Required  \
# 4  Product Dev  Prototype Development       Ethan 2024-01-02             18
# 5  Product Dev      Quality Assurance       Fiona 2024-01-20             10
# 6  Product Dev  User Interface Design     Gabriel 2024-02-04             25
#
#     End Date  Progress
# 4 2024-01-20      1.00
# 5 2024-01-30      0.78
# 6 2024-02-29      0.00
