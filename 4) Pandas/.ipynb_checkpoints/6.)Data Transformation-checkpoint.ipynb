# %%
import pandas as pd
df=pd.read_csv("1745501008647-data_cleaning_sample.csv");

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.sort_values("Age")
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.sort_values(["Age","Email"])
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2=df.sort_values(["Age","Email"],ascending=False)

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 4    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2.sort_index()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 4    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2["rank"]=df2["Age"].rank(method="dense")

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date  rank
# 0      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   4.0
# 1      NaN  28.0        Delhi      F     eve@domain.com         NaN   3.0
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 4    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 5    David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date  rank
# 0      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   6.0
# 1      NaN  28.0        Delhi      F     eve@domain.com         NaN   5.0
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021   3.0
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021   3.0
# 4    Alice  25.0     New York      F  alice@example.com  01-05-2021   3.0
# 5    David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN

# %%
df2.rename(columns={"Name":"First Name"})
# Out:
#   First Name   Age         City Gender              Email   Join Date  rank
# 0        Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   4.0
# 1        NaN  28.0        Delhi      F     eve@domain.com         NaN   3.0
# 2      Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 3      Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 4      Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 5      David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 6    Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 7    Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 8    Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date  rank
# 0      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   4.0
# 1      NaN  28.0        Delhi      F     eve@domain.com         NaN   3.0
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 4    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 5    David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN

# %%
df2.columns = ["Name", "Age", "City","Gender","Email","Join Date","Rank"]

# %%
df2.rename(index={0:"row1",1:"row2"})
# Out:
#          Name   Age         City Gender              Email   Join Date  rank
# row1      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   4.0
# row2      NaN  28.0        Delhi      F     eve@domain.com         NaN   3.0
# 2       Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 3       Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 4       Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 5       David  22.0       Mumbai      M  david@example.com  12-11-2019   1.0
# 6     Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 7     Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN
# 8     Charlie   NaN        Delhi      M    charlie@example  20-07-2021   NaN

# %%
df2=df2[[	"rank"	,"Age",	"City",	"Gender",	"Email"	,"Join Date",	"Name"]] # Reorder as desired

# %%
df2
# Out:
#    Name  Age         City Gender              Email   Join Date     Rank
# 0  30.0  4.0  Los Angeles      M    bob@example.com  15-06-2020      Bob
# 1  28.0  3.0        Delhi      F     eve@domain.com         NaN      NaN
# 2  25.0  2.0     New York      F  alice@example.com  01-05-2021    Alice
# 3  25.0  2.0     New York      F  alice@example.com  01-05-2021    Alice
# 4  25.0  2.0     New York      F  alice@example.com  01-05-2021    Alice
# 5  22.0  1.0       Mumbai      M  david@example.com  12-11-2019    David
# 6   NaN  NaN        Delhi      M    charlie@example  20-07-2021  Charlie
# 7   NaN  NaN        Delhi      M    charlie@example  20-07-2021  Charlie
# 8   NaN  NaN        Delhi      M    charlie@example  20-07-2021  Charlie

# %%
cols=["Age"]+[col for col in df2.columns if col!="Age"]
df2=df2[cols]

# %%
df2
# Out:
#     Age  rank         City Gender              Email   Join Date     Name
# 0  30.0   4.0  Los Angeles      M    bob@example.com  15-06-2020      Bob
# 1  28.0   3.0        Delhi      F     eve@domain.com         NaN      NaN
# 2  25.0   2.0     New York      F  alice@example.com  01-05-2021    Alice
# 3  25.0   2.0     New York      F  alice@example.com  01-05-2021    Alice
# 4  25.0   2.0     New York      F  alice@example.com  01-05-2021    Alice
# 5  22.0   1.0       Mumbai      M  david@example.com  12-11-2019    David
# 6   NaN   NaN        Delhi      M    charlie@example  20-07-2021  Charlie
# 7   NaN   NaN        Delhi      M    charlie@example  20-07-2021  Charlie
# 8   NaN   NaN        Delhi      M    charlie@example  20-07-2021  Charlie
