# %%
import pandas as pd
df=pd.read_csv("1745501008647-data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
#check missing data
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
#missing data count in each column
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
df2=df

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
#drop rows with null values
df2.dropna()
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
#drop column with null values
df2.dropna(axis=1)
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %%
#fill null values  with given value
df.fillna(1)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   1.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   1.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5        1  28.0        Delhi      F     eve@domain.com           1
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   1.0        Delhi      M    charlie@example  20-07-2021

# %%
#filling particular column null values
df["Age"].fillna(2)
# Out:
# 0    25.0
# 1     2.0
# 2    30.0
# 3     2.0
# 4    22.0
# 5    28.0
# 6    25.0
# 7    25.0
# 8     2.0
# Name: Age, dtype: float64

# %%
#filling particular column nulll value with mean of that column
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.000000
# 1    25.833333
# 2    30.000000
# 3    25.833333
# 4    22.000000
# 5    28.000000
# 6    25.000000
# 7    25.000000
# 8    25.833333
# Name: Age, dtype: float64

# %%
df["Age"]
# Out:
# 0    25.0
# 1     NaN
# 2    30.0
# 3     NaN
# 4    22.0
# 5    28.0
# 6    25.0
# 7    25.0
# 8     NaN
# Name: Age, dtype: float64

# %%
df.ffill() # Forward fill
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  25.0        Delhi      M    charlie@example  20-07-2021

# %%
df.bfill()  # Backward fill
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.duplicated()#return series True for duplicates
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates() # Remove duplicate rows
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
#check based on specific column by giving subset
df.duplicated(subset=["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates(subset=["Name","Age"])
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
#str operations it works like vectorized operation
df["Name"].str.lower()# Converts all names to lowercase.
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %%
df["City"].str.contains("delhi",case=False)# Checks if 'delhi' is in the city name, case-insensitive.
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# Name: City, dtype: bool

# %%
df["Email"].str.split("@")# Outputs a pandas Series where each element is a list of strings (the split parts). This is where a Python list comes into play, but the outer object is still a pandas Series.
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3      [charlie, example]
# 4    [david, example.com]
# 5       [eve, domain.com]
# 6    [alice, example.com]
# 7    [alice, example.com]
# 8      [charlie, example]
# Name: Email, dtype: object

# %%
#We can always chain methods like .str.strip().str.upper() for clean-up.
df["Name"].str.strip().str.upper()
# Out:
# 0      ALICE
# 1    CHARLIE
# 2        BOB
# 3    CHARLIE
# 4      DAVID
# 5        NaN
# 6      ALICE
# 7      ALICE
# 8    CHARLIE
# Name: Name, dtype: object

# %%
#type Conversion
type(df["Age"][0])
# Out:
# numpy.float64

# %%
df["Age"]=df["Age"].fillna(0)
df["Age"]=df["Age"].astype(int)

# %%
df["Age"]
# Out:
# 0    25
# 1     0
# 2    30
# 3     0
# 4    22
# 5    28
# 6    25
# 7    25
# 8     0
# Name: Age, dtype: int64

# %%
df["Join Date"]
# Out:
# 0    01-05-2021
# 1    20-07-2021
# 2    15-06-2020
# 3    20-07-2021
# 4    12-11-2019
# 5           NaN
# 6    01-05-2021
# 7    01-05-2021
# 8    20-07-2021
# Name: Join Date, dtype: object

# %%
df=df.ffill()

# %%
df["Join Date"]
# Out:
# 0    01-05-2021
# 1    20-07-2021
# 2    15-06-2020
# 4    12-11-2019
# 5    12-11-2019
# Name: Join Date, dtype: object

# %%
df["Join Date"]=pd.to_datetime(df["Join Date"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df["Join Date"]=pd.to_datetime(df["Join Date"])
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
df.dtypes
# Out:
# Name         object
# Age           int64
# City         object
# Gender       object
# Email        object
# Join Date    object
# dtype: object

# %%
df
# Out:
#       Name  Age         City Gender              Email   Join Date
# 0    Alice   25     New York      F  alice@example.com  01-05-2021
# 1  Charlie    0        Delhi      M    charlie@example  20-07-2021
# 2      Bob   30  Los Angeles      M    bob@example.com  15-06-2020
# 4    David   22       Mumbai      M  david@example.com  12-11-2019
# 5    David   28        Delhi      F     eve@domain.com  12-11-2019

# %%
df["Age Group"]=df["Age"].apply(lambda a:"Adult" if a>25 else "Minor")

# %%
df
# Out:
#       Name  Age         City Gender              Email   Join Date Age Group
# 0    Alice   25     New York      F  alice@example.com  01-05-2021     Minor
# 1  Charlie    0        Delhi      M    charlie@example  20-07-2021     Minor
# 2      Bob   30  Los Angeles      M    bob@example.com  15-06-2020     Adult
# 4    David   22       Mumbai      M  david@example.com  12-11-2019     Minor
# 5    David   28        Delhi      F     eve@domain.com  12-11-2019     Adult

# %%
dict={"F":"Female","M":"Male"}
df["Gender"]=df["Gender"].map(dict)

# %%
df
# Out:
#       Name  Age         City  Gender              Email   Join Date Age Group
# 0    Alice   25     New York  Female  alice@example.com  01-05-2021     Minor
# 1  Charlie    0        Delhi    Male    charlie@example  20-07-2021     Minor
# 2      Bob   30  Los Angeles    Male    bob@example.com  15-06-2020     Adult
# 4    David   22       Mumbai    Male  david@example.com  12-11-2019     Minor
# 5    David   28        Delhi  Female     eve@domain.com  12-11-2019     Adult

# %%
df["City"]=df["City"].replace({"Delhi":"New Delhi"})

# %%
df
# Out:
#       Name  Age         City  Gender              Email   Join Date Age Group
# 0    Alice   25     New York  Female  alice@example.com  01-05-2021     Minor
# 1  Charlie    0    New Delhi    Male    charlie@example  20-07-2021     Minor
# 2      Bob   30  Los Angeles    Male    bob@example.com  15-06-2020     Adult
# 4    David   22       Mumbai    Male  david@example.com  12-11-2019     Minor
# 5    David   28    New Delhi  Female     eve@domain.com  12-11-2019     Adult
